# %%
import pandas as pd

# %%
df = pd.read_csv('filename.csv')
df.head()
# Out:
#   CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0           M            Y               Y           0.0          427500.0
# 1           F            N               Y           1.0           90000.0
# 2           M            Y               Y           0.0          427500.0
# 3           M            N               Y           0.0          180000.0
# 4           M            Y               Y           0.0          112500.0
#
#   NAME_INCOME_TYPE            NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0          Working               Higher education     Civil marriage
# 1    State servant  Secondary / secondary special            Married
# 2          Working               Higher education     Civil marriage
# 3          Working               Higher education     Civil marriage
# 4          Working  Secondary / secondary special            Married
#
#    NAME_HOUSING_TYPE  DAYS_EMPLOYED  ...  FLAG_WORK_PHONE  FLAG_PHONE  \
# ...

# %%
df = df.drop('New_ID', axis=1)
df.head()
# Out:
#   CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0           M            Y               Y           0.0          427500.0
# 1           F            N               Y           1.0           90000.0
# 2           M            Y               Y           0.0          427500.0
# 3           M            N               Y           0.0          180000.0
# 4           M            Y               Y           0.0          112500.0
#
#   NAME_INCOME_TYPE            NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0          Working               Higher education     Civil marriage
# 1    State servant  Secondary / secondary special            Married
# 2          Working               Higher education     Civil marriage
# 3          Working               Higher education     Civil marriage
# 4          Working  Secondary / secondary special            Married
#
#    NAME_HOUSING_TYPE  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  \
# ...

# %%
df['DAYS_BIRTH_CLEAN'] = pd.to_datetime(df['DAYS_BIRTH_CLEAN'])
today = pd.Timestamp.today()
df['Age'] = today - df['DAYS_BIRTH_CLEAN'].dt.year

# %%
df.head()
# Out:
#   CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0           M            Y               Y           0.0          427500.0
# 1           F            N               Y           1.0           90000.0
# 2           M            Y               Y           0.0          427500.0
# 3           M            N               Y           0.0          180000.0
# 4           M            Y               Y           0.0          112500.0
#
#   NAME_INCOME_TYPE            NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0          Working               Higher education     Civil marriage
# 1    State servant  Secondary / secondary special            Married
# 2          Working               Higher education     Civil marriage
# 3          Working               Higher education     Civil marriage
# 4          Working  Secondary / secondary special            Married
#
#    NAME_HOUSING_TYPE  DAYS_EMPLOYED  ...  FLAG_WORK_PHONE  FLAG_PHONE  \
# ...

# %%
df['FLAG_OWN_REALTY'].value_counts()
# Out:
# Y    296862
# N    131225
# Name: FLAG_OWN_REALTY, dtype: int64

# %%
df['ADDRESS'] = df['ADDRESS'].astype(str)

# %%
df.replace({'FLAG_OWN_REALTY':{'N': 0, 'Y':1}, 'FLAG_OWN_CAR':{'N':0, 'Y':1}, 'CODE_GENDER':{'M':0, 'F':1}}, inplace=True)
