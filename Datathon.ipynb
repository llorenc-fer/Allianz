# %%
import pandas as pd

# Primera Descarga

DF = pd.read_csv("/Users/migueldiaz-maurinocarrera/Desktop/Datathon/main.csv")
DF2 = pd.read_csv("/Users/migueldiaz-maurinocarrera/Desktop/Datathon/address.csv")
DF3 = pd.read_csv("/Users/migueldiaz-maurinocarrera/Desktop/Datathon/paid_record.csv")

# %%
DF.head(10)
# Out:
#   CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0           M            Y               Y           0.0          427500.0
# 1           M            Y               Y           0.0          427500.0
# 2           M            Y               Y           0.0          112500.0
# 3           F            N               Y           0.0          270000.0
# 4           F          NaN               Y           0.0          270000.0
# 5           F            N               Y           0.0          270000.0
# 6           F            N               Y           0.0          270000.0
# 7           F            N               Y           0.0          283500.0
# 8           F            N               Y           0.0          283500.0
# 9           F            N               Y           0.0          283500.0
#
#        NAME_INCOME_TYPE            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# ...

# %%
DF2.head(10)
# Out:
#      New_ID                               ADDRESS
# 0  5008804L           06042, CT, 31 Mitchell Road
# 1  5008805G  72703, AR, 1189 Northwest End Avenue
# 2  5008806D          72701, AR, 218 Shipley Alley
# 3  5008808I    3138 P Street Northwest, 20007, DC
# 4  5008809Z          2405 230th Street, 21122, MD
# 5  5008810C              32404, FL, 7041 Coe Road
# 6  5008811J         36116, AL, 5836 Red Barn Road
# 7  5008812N      80004, CO, 8380 West 67th Avenue
# 8  5008813K            06040, CT, 824 Main Street
# 9  5008814J          93667, CA, 29104 Quartz Lane

# %%
DF2['New_ID'] = DF2['New_ID'].str.extract('(\d+)').astype(int)
DF2['New_ID']
# Out:
# 0         5008804
# 1         5008805
# 2         5008806
# 3         5008808
# 4         5008809
#            ...
# 438752    5680433
# 438753    5353755
# 438754    5689895
# 438755    5833391
# 438756    6395895
# Name: New_ID, Length: 438757, dtype: int64

# %%
DF2.head(10)
# Out:
#     New_ID                               ADDRESS
# 0  5008804           06042, CT, 31 Mitchell Road
# 1  5008805  72703, AR, 1189 Northwest End Avenue
# 2  5008806          72701, AR, 218 Shipley Alley
# 3  5008808    3138 P Street Northwest, 20007, DC
# 4  5008809          2405 230th Street, 21122, MD
# 5  5008810              32404, FL, 7041 Coe Road
# 6  5008811         36116, AL, 5836 Red Barn Road
# 7  5008812      80004, CO, 8380 West 67th Avenue
# 8  5008813            06040, CT, 824 Main Street
# 9  5008814          93667, CA, 29104 Quartz Lane

# %%
type(DF2['Main_ID'][0])
# Out:
# list

# %%
DF3.head(10)
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C
# 5  5001712              -1      C
# 6  5001712              -2      C
# 7  5001712              -3      C
# 8  5001712              -4      C
# 9  5001712              -5      C

# %%
import re

DF2['zip_codes'] = re.findall("\d{5}", DF2['ADDRESS'])

print(DF2['zip_codes'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 3>()
#       1 import re
# ----> 3 DF2['zip_codes'] = re.findall("\d{5}", DF2['ADDRESS'])
#       5 print(DF2['zip_codes'])
#
# File ~/opt/anaconda3/envs/env_IRL/lib/python3.8/re.py:241, in findall(pattern, string, flags)
#     233 def findall(pattern, string, flags=0):
#     234     """Return a list of all non-overlapping matches in the string.
#     235
#     236     If one or more capturing groups are present in the pattern, return
#    (...)
#     239
#     240     Empty matches are included in the result."""
# --> 241     return _compile(pattern, flags).findall(string)
#
# TypeError: expected string or bytes-like object

# %%
DF3.head(10)
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C
# 5  5001712              -1      C
# 6  5001712              -2      C
# 7  5001712              -3      C
# 8  5001712              -4      C
# 9  5001712              -5      C

# %%
DF3['STATUS'].value_counts()
# Out:
# C    442031
# 0    383120
# X    209230
# 1     11090
# 5      1693
# 2       868
# 3       320
# 4       223
# Name: STATUS, dtype: int64

# %%
DF3[DF3['STATUS'] == 'X'].value_counts()
# Out:
# ID       MONTHS_BALANCE  STATUS
# 5001711   0              X         1
# 5095238  -14             X         1
#          -24             X         1
#          -23             X         1
#          -22             X         1
#                                   ..
# 5036130  -30             X         1
# 5036142  -48             X         1
# 5036143  -12             X         1
# 5036145  -21             X         1
# 5150483   0              X         1
# Length: 209230, dtype: int64

# %%
DF3['MONTHS_BALANCE'].value_counts()
# Out:
# -1     34436
# -2     34209
#  0     33856
# -3     33854
# -4     33365
#        ...
# -56     2109
# -57     1649
# -58     1255
# -59      820
# -60      415
# Name: MONTHS_BALANCE, Length: 61, dtype: int64

# %%
len(DF['Letter'])
# Out:
# 438757

# %%
len(DF2['ADDRESS'])
# Out:
# 438757

# %%
len(DF3['STATUS'])
# Out:
# 1048575

# %%
DF.describe()
# Out:
#         CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_EMPLOYED  FLAG_MOBIL  \
# count  427826.000000      4.276240e+05  427784.000000    427690.0
# mean        0.427342      1.875433e+05   60470.590104         1.0
# std         0.724978      1.101912e+05  138687.537051         0.0
# min         0.000000      2.610000e+04  -17531.000000         1.0
# 25%         0.000000      1.215000e+05   -3105.000000         1.0
# 50%         0.000000      1.620000e+05   -1468.000000         1.0
# 75%         1.000000      2.250000e+05    -372.000000         1.0
# max        19.000000      6.750000e+06  365243.000000         1.0
#
#        FLAG_WORK_PHONE     FLAG_PHONE     FLAG_EMAIL  CNT_FAM_MEMBERS  \
# count    427715.000000  427674.000000  427770.000000    427823.000000
# mean          0.206119       0.287836       0.108261         2.194662
# std           0.404517       0.452755       0.310711         0.897227
# min           0.000000       0.000000       0.000000         1.000000
# ...

# %%
import re

DF2['zip_codes'] = re.findall("\d{5}", DF2['ADDRESS'])

print(DF2['zip_codes'])

# %%
merged_1 = DF.merge(DF2, left_on = 'Main_ID', right_on = 'New_ID')

# %%
merged_1.head(10)
# Out:
#   CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0           M            Y               Y           0.0          427500.0
# 1           F            N               Y           1.0           90000.0
# 2           M            Y               Y           0.0          427500.0
# 3           M            N               Y           0.0          180000.0
# 4           M            Y               Y           0.0          112500.0
# 5           F            N               N           0.0           49500.0
# 6           F            N               Y           0.0          270000.0
# 7           M            Y               N           0.0          270000.0
# 8           F          NaN               Y           0.0          270000.0
# 9           F            N               Y           0.0          135000.0
#
#        NAME_INCOME_TYPE            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# ...

# %%
df.to_csv('filename.csv', index=False)
