# %%
import pandas as pd
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.image import imread
import plotly.express as px
import plotly.graph_objs as go
import plotly.graph_objects as go

# %%
df1 = pd.read_csv(r'C:\Users\lluri\Documents\samplerepo\Upgrade Hub\Practice Sheet\Allianz\Datathon_VF.csv')
# df2 = pd.read_csv('address.csv')
# df3 = pd.read_csv('paid_record.csv')
# merged_df = pd.merge(df1, df2, left_on='Main_ID', right_on='New_ID')

# %%
df1.head()
# Out:
#   CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0           M            Y               Y           0.0          427500.0
# 1           M            Y               Y           0.0          427500.0
# 2           M            Y               Y           0.0          112500.0
# 3           F            N               Y           0.0          270000.0
# 4           F          NaN               Y           0.0          270000.0
#
#        NAME_INCOME_TYPE            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# 0               Working               Higher education        Civil marriage
# 1               Working               Higher education        Civil marriage
# 2               Working  Secondary / secondary special               Married
# 3  Commercial associate  Secondary / secondary special  Single / not married
# 4  Commercial associate  Secondary / secondary special  Single / not married
#
# ...

# %%
df1.rename(columns={'Main_ID': 'ID'}, inplace=True)

# %%
df2.rename(columns={'New_ID': 'ID'}, inplace=True)

# %%
pd.merge(df1, df2, on='ID')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 pd.merge(df1, df2, on='ID')
#
# File c:\Users\lluri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
# ...

# %%
df1['DAYS_BIRTH_CLEAN'] = pd.to_datetime(df1['DAYS_BIRTH_CLEAN'])

# %%
df1['Age'] = 2023 - df1['DAYS_BIRTH_CLEAN'].dt.year

fig = px.histogram(df1, x ="Age", color='CODE_GENDER', template='plotly_white') #marker_color=colors)
fig.update_layout(title="Distribución por edad", xaxis_title="Age", yaxis_title="Frequency", template = 'plotly_dark',)
fig.show()

# %%
values = df1['CNT_FAM_MEMBERS'].value_counts().values
fig = px.bar(x=df1['CNT_FAM_MEMBERS'].value_counts().index, 
            y=df1['CNT_FAM_MEMBERS'].value_counts().values,
            color=values)
fig.update_layout(title="Family Members", 
                xaxis_title="Type", 
                yaxis_title="Total Listings",
                template = 'plotly_dark')
fig.show()

# %%
df1.head()
# Out:
#   CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0           M            Y               Y           0.0          427500.0
# 1           M            Y               Y           0.0          427500.0
# 2           M            Y               Y           0.0          112500.0
# 3           F            N               Y           0.0          270000.0
# 4           F          NaN               Y           0.0          270000.0
#
#        NAME_INCOME_TYPE            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# 0               Working               Higher education        Civil marriage
# 1               Working               Higher education        Civil marriage
# 2               Working  Secondary / secondary special               Married
# 3  Commercial associate  Secondary / secondary special  Single / not married
# 4  Commercial associate  Secondary / secondary special  Single / not married
#
# ...

# %%
df1.dtypes
# Out:
# CODE_GENDER                    object
# FLAG_OWN_CAR                   object
# FLAG_OWN_REALTY                object
# CNT_CHILDREN                  float64
# AMT_INCOME_TOTAL              float64
# NAME_INCOME_TYPE               object
# NAME_EDUCATION_TYPE            object
# NAME_FAMILY_STATUS             object
# NAME_HOUSING_TYPE              object
# DAYS_EMPLOYED                 float64
# FLAG_MOBIL                    float64
# FLAG_WORK_PHONE               float64
# FLAG_PHONE                    float64
# FLAG_EMAIL                    float64
# OCCUPATION_TYPE                object
# CNT_FAM_MEMBERS               float64
# DAYS_BIRTH_CLEAN       datetime64[ns]
# Letter                         object
# Main_ID                         int64
# dtype: object

# %%
df1.isnull().sum().sum()
# Out:
# 317727

# %%
df1.shape
# Out:
# (438757, 19)

# %%
df2.head()
# Out:
#          ID                               ADDRESS
# 0  5008811J           06042, CT, 31 Mitchell Road
# 1  5008811J  72703, AR, 1189 Northwest End Avenue
# 2  5008811J          72701, AR, 218 Shipley Alley
# 3  5008811J    3138 P Street Northwest, 20007, DC
# 4  5008811J          2405 230th Street, 21122, MD

# %%
df2['ID'] = df2['ID'].str.replace('\D+', '', regex=True)

# %%
df2.head()
# Out:
#         ID                               ADDRESS
# 0  5008804           06042, CT, 31 Mitchell Road
# 1  5008805  72703, AR, 1189 Northwest End Avenue
# 2  5008806          72701, AR, 218 Shipley Alley
# 3  5008808    3138 P Street Northwest, 20007, DC
# 4  5008809          2405 230th Street, 21122, MD

# %%
df1['Main_ID'].nunique()
# Out:
# 438510

# %%
df1['OCCUPATION_TYPE'].isnull().sum()
# Out:
# 141805

# %%
percent_missing = df1.isnull().sum() * 100 / len(df1)
print(percent_missing)
# Out:
# CODE_GENDER             2.475858
# FLAG_OWN_CAR            2.518934
# FLAG_OWN_REALTY         2.495915
# CNT_CHILDREN            2.491356
# AMT_INCOME_TOTAL        2.537395
# NAME_INCOME_TYPE        2.515971
# NAME_EDUCATION_TYPE     2.530558
# NAME_FAMILY_STATUS      2.503664
# NAME_HOUSING_TYPE       2.521669
# DAYS_EMPLOYED           2.500929
# FLAG_MOBIL              2.522353
# FLAG_WORK_PHONE         2.516655
# FLAG_PHONE              2.526000
# FLAG_EMAIL              2.504120
# OCCUPATION_TYPE        32.319712
# CNT_FAM_MEMBERS         2.492040
# DAYS_BIRTH_CLEAN        2.442126
# Letter                  0.000000
# Main_ID                 0.000000
# dtype: float64

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (438757, 19)
# (438757, 2)
# (1048575, 3)

# %%
df2.head()
# Out:
#      New_ID                               ADDRESS
# 0  5008804L           06042, CT, 31 Mitchell Road
# 1  5008805G  72703, AR, 1189 Northwest End Avenue
# 2  5008806D          72701, AR, 218 Shipley Alley
# 3  5008808I    3138 P Street Northwest, 20007, DC
# 4  5008809Z          2405 230th Street, 21122, MD

# %%
import re

# %%
df2.head()
# Out:
#           ID                               ADDRESS
# 0  [5008811]           06042, CT, 31 Mitchell Road
# 1  [5008811]  72703, AR, 1189 Northwest End Avenue
# 2  [5008811]          72701, AR, 218 Shipley Alley
# 3  [5008811]    3138 P Street Northwest, 20007, DC
# 4  [5008811]          2405 230th Street, 21122, MD

# %%
df3.head(20)
# Out:
#          ID  MONTHS_BALANCE STATUS
# 0   5001711               0      X
# 1   5001711              -1      0
# 2   5001711              -2      0
# 3   5001711              -3      0
# 4   5001712               0      C
# 5   5001712              -1      C
# 6   5001712              -2      C
# 7   5001712              -3      C
# 8   5001712              -4      C
# 9   5001712              -5      C
# 10  5001712              -6      C
# 11  5001712              -7      C
# 12  5001712              -8      C
# 13  5001712              -9      0
# 14  5001712             -10      0
# 15  5001712             -11      0
# 16  5001712             -12      0
# 17  5001712             -13      0
# 18  5001712             -14      0
# 19  5001712             -15      0

# %%
df3.nunique()
# Out:
# ID                45985
# MONTHS_BALANCE       61
# STATUS                8
# dtype: int64

# %%
df1.dtypes
# Out:
# CODE_GENDER             object
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN           float64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_EMPLOYED          float64
# FLAG_MOBIL             float64
# FLAG_WORK_PHONE        float64
# FLAG_PHONE             float64
# FLAG_EMAIL             float64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# DAYS_BIRTH_CLEAN        object
# Letter                  object
# Main_ID                  int64
# dtype: object

# %%
df2.dtypes
# Out:
# New_ID     object
# ADDRESS    object
# dtype: object

# %%
df2['ID'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df2['ID'].astype(int)
#
# File c:\Users\lluri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File c:\Users\lluri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\managers.py:450, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...
